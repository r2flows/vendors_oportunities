# %%
import pandas as pd

# %%
top = pd.read_csv('top_5_productos_geozona.csv')
top[(top['vendor_id'] == 1303)]
# Out:
#       point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 1897              1616     7501537161163              87.0         19.850
# 1940              1616     7501573900443             121.0          5.050
# 1972              1616     7501825304142              33.0         12.500
# 2009              1616     7502227877722               4.0         90.550
# 2011              1729     7501573905417              15.0         14.350
# 2020              2277     7503001008684               5.0         42.410
# 2039              2076     7503001009117               3.0         64.400
# 2062              1616     7502211783657               3.0         66.680
# 2064              1616     7501258203395               5.0         26.350
# 2100              1477      780083142704               5.0         18.520
# 2168              1729     7503001007090               3.0         28.800
# 2224              2119     7503001007199               1.0         33.020
# 2234              2076     7501573909859               2.0         57.600
# 2256              1601     7501048692187               2.0         17.190
# 2259              1601     7502211783275               1.0         19.859
# 2276              2119     7501573904755               4.0         38.240
#
#               geo_zone  vendor_id              name  base_price  percentage  \
# 1897  Estado de México       1303  Estado de México       19.81         0.0
# 1940  Estado de México       1303  Estado de México        4.70         0.0
# 1972  Estado de México       1303  Estado de México       10.56         0.0
# 2009  Estado de México       1303  Estado de México       53.03         0.0
# 2011  Estado de México       1303  Estado de México       13.90         0.0
# 2020  Estado de México       1303  Estado de México       36.60         0.0
# 2039  Estado de México       1303  Estado de México       49.00         0.0
# 2062  Estado de México       1303  Estado de México       40.53         0.0
# 2064  Estado de México       1303  Estado de México       24.17         0.0
# 2100  Estado de México       1303  Estado de México       17.78         0.0
# 2168  Estado de México       1303  Estado de México       18.65         0.0
# 2224  Estado de México       1303  Estado de México       29.20         0.0
# 2234  Estado de México       1303  Estado de México       13.72         0.0
# 2256  Estado de México       1303  Estado de México       11.04         0.0
# 2259  Estado de México       1303  Estado de México       19.68         0.0
# 2276  Estado de México       1303  Estado de México        2.10         0.0
#
#       precio_vendedor  precio_total_vendedor  status  valor_total_vendedor
# 1897            19.81                1723.47     NaN               1723.47
# 1940             4.70                 568.70     NaN                568.70
# 1972            10.56                 348.48     NaN                348.48
# 2009            53.03                 212.12     NaN                212.12
# 2011            13.90                 208.50     1.0                208.50
# 2020            36.60                 183.00     1.0                183.00
# 2039            49.00                 147.00     NaN                147.00
# 2062            40.53                 121.59     NaN                121.59
# 2064            24.17                 120.85     NaN                120.85
# 2100            17.78                  88.90     1.0                 88.90
# 2168            18.65                  55.95     1.0                 55.95
# 2224            29.20                  29.20     NaN                 29.20
# 2234            13.72                  27.44     NaN                 27.44
# 2256            11.04                  22.08     NaN                 22.08
# 2259            19.68                  19.68     NaN                 19.68
# 2276             2.10                   8.40     NaN                  8.40

# %%
top[(top['name'] == 'CDMX')] #& (top['name']=='CDMX')]
# Out:
# Empty DataFrame
# Columns: [point_of_sale_id, super_catalog_id, unidades_pedidas, precio_minimo, geo_zone, vendor_id, name, base_price, percentage, precio_vendedor, precio_total_vendedor, status, valor_total_vendedor]
# Index: []

# %%
orders = pd.read_csv('orders_delivered_pos_vendor_geozone.csv')
orders[(orders['vendor_id']==10608) & (orders['geo_zone']=='CDMX')]
# Out:
#        point_of_sale_id  super_catalog_id  order_id           order_date  \
# 27326              1794        8400009265    242872  2025-01-25 03:00:05
# 27344              1794     7501159526029    242872  2025-01-25 03:00:05
# 27346              1794     7501258203586    242872  2025-01-25 03:00:05
# 27347              1794     7501258203593    242872  2025-01-25 03:00:05
# 27349              1794     7501299370360    242872  2025-01-25 03:00:05
# 27358              1794     7501537102982    242872  2025-01-25 03:00:05
# 27359              1794     7501537102999    242872  2025-01-25 03:00:05
# 27363              1794     7501573903260    242872  2025-01-25 03:00:05
# 27373              1794     7502009741753    242872  2025-01-25 03:00:05
# 27377              1794     7502211784043    242872  2025-01-25 03:00:05
# 27388              1794     7503027446279    242872  2025-01-25 03:00:05
# 27393              1794      821998000250    242872  2025-01-25 03:00:05
# 82132              2324     7501537102999    248064  2025-02-07 17:30:07
# 82135              2324     7502223111202    248064  2025-02-07 17:30:07
#
#        unidades_pedidas  precio_minimo  vendor_id  valor_vendedor geo_zone  \
# 27326               1.0         85.940      10608          85.940     CDMX
# 27344               3.0        288.248      10608         864.744     CDMX
# 27346               3.0         29.550      10608          88.650     CDMX
# 27347               1.0         23.500      10608          23.500     CDMX
# 27349               8.0         32.280      10608         258.240     CDMX
# 27358               2.0         20.000      10608          40.000     CDMX
# 27359               7.0         10.500      10608          73.500     CDMX
# 27363               3.0         14.770      10608          44.310     CDMX
# 27373               1.0         12.140      10608          12.140     CDMX
# 27377               1.0         28.870      10608          28.870     CDMX
# 27388              10.0         22.107      10608         221.070     CDMX
# 27393               1.0         41.180      10608          41.180     CDMX
# 82132              20.0         10.580      10608         211.600     CDMX
# 82135               3.0        106.280      10608         318.840     CDMX
#
#       country
# 27326      MX
# 27344      MX
# 27346      MX
# 27347      MX
# 27349      MX
# 27358      MX
# 27359      MX
# 27363      MX
# 27373      MX
# 27377      MX
# 27388      MX
# 27393      MX
# 82132      MX
# 82135      MX

# %%
orders = pd.read_csv('orders_delivered_pos_vendor_geozone.csv')

# %%
orders
# Out:
#        point_of_sale_id  super_catalog_id  order_id           order_date  \
# 0                  1182          75000950    239442  2025-01-16 02:27:02
# 1                  1182          75001865    244731  2025-01-30 01:21:43
# 2                  1182          75001872    245977  2025-02-03 00:02:51
# 3                  1182          75002794    239442  2025-01-16 02:27:02
# 4                  1182          75006433    237002  2025-01-09 03:54:07
# ...                 ...               ...       ...                  ...
# 82231              2312     7502216792920    236410  2025-01-07 21:46:02
# 82232              2312     7502227427392    236410  2025-01-07 21:46:02
# 82233              2174     7502009744129    247585  2025-02-06 18:35:52
# 82234              2174     7503003738879    247573  2025-02-06 18:18:06
# 82235              2175     7502208891228    249471  2025-02-11 20:37:42
#
#        unidades_pedidas  precio_minimo  vendor_id  valor_vendedor  \
# 0                  12.0         14.820         11          177.84
# 1                   5.0         42.710         11          213.55
# 2                   6.0         27.040         11          162.24
# 3                   6.0         25.640         11          153.84
# 4                  10.0         12.590         34          125.90
# ...                 ...            ...        ...             ...
# 82231              40.0         45.510         24         1820.40
# 82232              20.0         18.030         42          360.60
# 82233             200.0         35.350      10277         7070.00
# 82234             300.0         22.860      10277         6858.00
# 82235            1000.0         14.599      10267        14599.00
#
#                geo_zone country
# 0                  CDMX      MX
# 1                  CDMX      MX
# 2                  CDMX      MX
# 3                  CDMX      MX
# 4                  CDMX      MX
# ...                 ...     ...
# 82231         Michoacán      MX
# 82232         Michoacán      MX
# 82233  Estado de México      MX
# 82234  Estado de México      MX
# 82235           Jalisco      MX
#
# [82236 rows x 10 columns]

# %%
df_pos_address = pd.read_csv('pos_address.csv')

# %%
def obtener_geo_zone(address):
    partes = address.split(', ')
    return ', '.join(partes[-2:-1])
    
df_pos_address['geo_zone'] = df_pos_address['address'].apply(obtener_geo_zone)

# %%
df_pedidos = pd.read_csv('orders_simple.csv')
df_proveedores = pd.read_csv('vendors_catalog.csv')
pos_geo_zones = df_pos_address[['point_of_sale_id','geo_zone']]
pos_geo_zones
# Out:
#       point_of_sale_id      geo_zone
# 0                    4  Buenos Aires
# 1                    5  Buenos Aires
# 2                   10  Buenos Aires
# 3                   11  Buenos Aires
# 4                   12  Buenos Aires
# ...                ...           ...
# 2333              2341  Cundinamarca
# 2334              2342         Sucre
# 2335              2343     Querétaro
# 2336              2344     Chihuahua
# 2337              2345       Jalisco
#
# [2338 rows x 2 columns]

# %%
df_proveedores['percentage'].fillna(0,inplace=True)
# Out:
# /tmp/ipykernel_4936/3916416807.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_proveedores['percentage'].fillna(0,inplace=True)

# %%
df_proveedores[df_proveedores['percentage'].isna()]
# Out:
# Empty DataFrame
# Columns: [vendor_id, super_catalog_id, name, base_price, percentage]
# Index: []

# %%
filtro = pos_geo_zones['geo_zone'].str.contains(r'\.')
pos_geo_zones[filtro]['geo_zone'].unique()
pos_geo_zones['geo_zone'] = pos_geo_zones['geo_zone'].replace({'B.C.S.':'Baja California Sur', 'Qro.':'Querétaro', 'Jal.':'Jalisco','Pue.':'Puebla', 'Méx.':'CDMX','Oax.':'Oaxaca','Chih.':'Chihuahua','Coah.':'Coahuila de Zaragoza','Mich.':'Michoacán de Ocampo', 'Ver.':'Veracruz de Ignacio de la Llave', 'Chis.':'Chiapas','N.L.':'Nuevo León','Hgo.':'Hidalgo','Tlax.':'Tlaxcala','Tamps.':'Tamaulipas','Yuc.':'Yucatan','Mor.':'Morelos','Sin.':'Sinaloa','S.L.P.':'San Luis Potosí','Q.R.':'Quintana Roo','Dgo.':'Durango','B.C.':'Baja California','Gto.':'Guanajuato','Camp.':'Campeche','Tab.':'Tabasco','Son.':'Sonora','Gro.':'Guerrero','Zac.':'Zacatecas','Ags.':'Aguascalientes', 'Nay.':'Nayarit'})
# Out:
# /tmp/ipykernel_4936/1442705292.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pos_geo_zones['geo_zone'] = pos_geo_zones['geo_zone'].replace({'B.C.S.':'Baja California Sur', 'Qro.':'Querétaro', 'Jal.':'Jalisco','Pue.':'Puebla', 'Méx.':'CDMX','Oax.':'Oaxaca','Chih.':'Chihuahua','Coah.':'Coahuila de Zaragoza','Mich.':'Michoacán de Ocampo', 'Ver.':'Veracruz de Ignacio de la Llave', 'Chis.':'Chiapas','N.L.':'Nuevo León','Hgo.':'Hidalgo','Tlax.':'Tlaxcala','Tamps.':'Tamaulipas','Yuc.':'Yucatan','Mor.':'Morelos','Sin.':'Sinaloa','S.L.P.':'San Luis Potosí','Q.R.':'Quintana Roo','Dgo.':'Durango','B.C.':'Baja California','Gto.':'Guanajuato','Camp.':'Campeche','Tab.':'Tabasco','Son.':'Sonora','Gro.':'Guerrero','Zac.':'Zacatecas','Ags.':'Aguascalientes', 'Nay.':'Nayarit'})

# %%
df_proveedores_nacional = df_proveedores[df_proveedores['name'] == 'México'].copy()
df_proveedores_regional = df_proveedores[df_proveedores['name'] != 'México'].copy()

df_pedidos_zonas = pd.merge(df_pedidos, pos_geo_zones, on='point_of_sale_id', how='left')
df_pedidos_zonas = df_pedidos_zonas[df_pedidos_zonas['unidades_pedidas']>0]


df_pedidos_proveedores_nacional = pd.merge(df_pedidos_zonas, df_proveedores_nacional, on = 'super_catalog_id', how = 'inner')

df_pedidos_proveedores_nacional=df_pedidos_proveedores_nacional[df_pedidos_proveedores_nacional['unidades_pedidas']>0]

df_pedidos_proveedores_regional = pd.merge(df_pedidos_zonas, df_proveedores_regional, left_on = ['super_catalog_id','geo_zone'], right_on = ['super_catalog_id','name'], how = 'inner')

df_pedidos_proveedores_regional=df_pedidos_proveedores_regional[df_pedidos_proveedores_regional['unidades_pedidas']>0]


df_pedidos_proveedores_nacional['base_price'] = df_pedidos_proveedores_nacional['base_price'].astype(float)
#df_proveedores['precio_vendedor']=df_proveedores['precio_vendedor'].astype(float)
df_pedidos_proveedores_nacional['percentage'] = df_pedidos_proveedores_nacional['percentage'].astype(float)

df_pedidos_proveedores_regional['base_price'] = df_pedidos_proveedores_regional['base_price'].astype(float)
#df_proveedores['precio_vendedor']=df_proveedores['precio_vendedor'].astype(float)
df_pedidos_proveedores_regional['percentage'] = df_pedidos_proveedores_regional['percentage'].astype(float)


df_pedidos_proveedores_nacional['precio_vendedor'] = df_pedidos_proveedores_nacional['base_price'] + (df_pedidos_proveedores_nacional['base_price'] * df_pedidos_proveedores_nacional['percentage'] / 100)
df_pedidos_proveedores_regional['precio_vendedor'] = df_pedidos_proveedores_regional['base_price'] + (df_pedidos_proveedores_regional['base_price'] * df_pedidos_proveedores_regional['percentage'] / 100)


df_pedidos_proveedores = pd.concat([df_pedidos_proveedores_regional, df_pedidos_proveedores_nacional], axis=0)
df_pedidos_proveedores_unique = df_pedidos_proveedores.drop_duplicates(subset=['super_catalog_id', 'vendor_id', 'geo_zone'])

df_pedidos_proveedores_unique['precio_total_vendedor'] = df_pedidos_proveedores_unique['unidades_pedidas'].astype(float) * df_pedidos_proveedores_unique['precio_vendedor'].astype(float)
# Out:
# /tmp/ipykernel_4936/1689331529.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pedidos_proveedores_unique['precio_total_vendedor'] = df_pedidos_proveedores_unique['unidades_pedidas'].astype(float) * df_pedidos_proveedores_unique['precio_vendedor'].astype(float)

# %%
df_pedidos_proveedores_unique
# Out:
#         point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 0                   1238        8400005656               1.0          64.48
# 1                   1748        8400005656               1.0          48.79
# 2                   1291        8400005823               5.0          45.04
# 3                   1238       20800753067               4.0          78.48
# 4                   1679       20800753067               3.0          81.33
# ...                  ...               ...               ...            ...
# 150667              1824      891671002277               1.0         507.87
# 150671              2306      891671002277               1.0         579.88
# 150672              1320     9002240001022               2.0         113.15
# 150673              1311       93815704270               1.0         164.51
# 150674              1601       93815704270               1.0         164.51
#
#                 geo_zone  vendor_id        name  base_price  percentage  \
# 0                Hidalgo       1161     Hidalgo     51.1182         0.0
# 1                Chiapas       1151     Chiapas     58.0300         0.0
# 2                Hidalgo       1161     Hidalgo     52.3506         0.0
# 3                Hidalgo       1161     Hidalgo     91.8182         0.0
# 4             Guanajuato       1161  Guanajuato     91.8182         0.0
# ...                  ...        ...         ...         ...         ...
# 150667           Durango       1156      México    534.6000         0.0
# 150671            Oaxaca       1156      México    534.6000         0.0
# 150672            Sonora       1156      México    110.0200         0.0
# 150673              CDMX       1159      México    189.1496         0.0
# 150674  Estado de México       1159      México    189.1496         0.0
#
#         precio_vendedor  precio_total_vendedor
# 0               51.1182                51.1182
# 1               58.0300                58.0300
# 2               52.3506               261.7530
# 3               91.8182               367.2728
# 4               91.8182               275.4546
# ...                 ...                    ...
# 150667         534.6000               534.6000
# 150671         534.6000               534.6000
# 150672         110.0200               220.0400
# 150673         189.1496               189.1496
# 150674         189.1496               189.1496
#
# [85333 rows x 11 columns]

# %%
df_vendors_pos = pd.read_csv('vendor_pos_relations.csv')

# %%
df_pedidos_proveedores_unique = pd.merge(df_pedidos_proveedores_unique,df_vendors_pos,on = ['point_of_sale_id','vendor_id'], how = 'left')

# %%
df_precio_inferior_por_vendor = df_pedidos_proveedores_unique[df_pedidos_proveedores_unique['precio_vendedor'].astype(float) < df_pedidos_proveedores_unique['precio_minimo'].astype(float)]

        # Calcular el total de productos con precio inferior para cada vendor
productos_con_precio_inferior_por_vendor = df_precio_inferior_por_vendor.groupby('vendor_id')['super_catalog_id'].nunique().reset_index()
productos_con_precio_inferior_por_vendor.columns = ['vendor_id', 'total_productos_con_precio_inferior']

        # Calcular el valor total (unidades * precio_vendedor) donde el vendor tiene un precio inferior para cada vendor
df_precio_inferior_por_vendor['valor_total_vendedor'] = df_precio_inferior_por_vendor['unidades_pedidas'].astype(float) * df_precio_inferior_por_vendor['precio_vendedor'].astype(float)

        # Calcular la suma de productos donde el vendor tiene un precio inferior para cada vendor
        # Agrupar por vendor y sumar el valor total donde el vendor tiene un precio inferior
suma_valor_total_precio_inferior_por_vendor = df_precio_inferior_por_vendor.groupby('vendor_id')['valor_total_vendedor'].sum().reset_index()
suma_valor_total_precio_inferior_por_vendor.columns = ['vendor_id', 'suma_valor_total_vendedor']


#csv_buffer_10 = productos_con_precio_inferior_por_vendor_90.to_csv(index = False)
#csv_buffer_11 = suma_valor_total_precio_inferior_por_vendor_90.to_csv(index = False)


        # PARETO BONDS

idx_min_price_per_product = df_precio_inferior_por_vendor.groupby('super_catalog_id')['precio_vendedor'].idxmin()

        # Crear un nuevo DataFrame con solo los vendors que ofrecen el menor precio por cada producto
df_mejor_precio_por_producto = df_precio_inferior_por_vendor.loc[idx_min_price_per_product].reset_index(drop=True)
# Out:
# /tmp/ipykernel_4936/2931396268.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_precio_inferior_por_vendor['valor_total_vendedor'] = df_precio_inferior_por_vendor['unidades_pedidas'].astype(float) * df_precio_inferior_por_vendor['precio_vendedor'].astype(float)

# %%
df_pedidos_proveedores_unique
# Out:
#        point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 0                  1238        8400005656               1.0          64.48
# 1                  1748        8400005656               1.0          48.79
# 2                  1291        8400005823               5.0          45.04
# 3                  1238       20800753067               4.0          78.48
# 4                  1679       20800753067               3.0          81.33
# ...                 ...               ...               ...            ...
# 85328              1824      891671002277               1.0         507.87
# 85329              2306      891671002277               1.0         579.88
# 85330              1320     9002240001022               2.0         113.15
# 85331              1311       93815704270               1.0         164.51
# 85332              1601       93815704270               1.0         164.51
#
#                geo_zone  vendor_id        name  base_price  percentage  \
# 0               Hidalgo       1161     Hidalgo     51.1182         0.0
# 1               Chiapas       1151     Chiapas     58.0300         0.0
# 2               Hidalgo       1161     Hidalgo     52.3506         0.0
# 3               Hidalgo       1161     Hidalgo     91.8182         0.0
# 4            Guanajuato       1161  Guanajuato     91.8182         0.0
# ...                 ...        ...         ...         ...         ...
# 85328           Durango       1156      México    534.6000         0.0
# 85329            Oaxaca       1156      México    534.6000         0.0
# 85330            Sonora       1156      México    110.0200         0.0
# 85331              CDMX       1159      México    189.1496         0.0
# 85332  Estado de México       1159      México    189.1496         0.0
#
#        precio_vendedor  precio_total_vendedor  status
# 0              51.1182                51.1182     1.0
# 1              58.0300                58.0300     NaN
# 2              52.3506               261.7530     0.0
# 3              91.8182               367.2728     1.0
# 4              91.8182               275.4546     NaN
# ...                ...                    ...     ...
# 85328         534.6000               534.6000     0.0
# 85329         534.6000               534.6000     NaN
# 85330         110.0200               220.0400     0.0
# 85331         189.1496               189.1496     NaN
# 85332         189.1496               189.1496     NaN
#
# [85333 rows x 12 columns]

# %%
min_prices = pd.read_csv('top_5_productos_geozona.csv')

# %%
import pandas as pd
import numpy as np

def analyze_price_differences(vendors_catalog_path, min_prices_path):
    # Leer los archivos CSV
    min_prices_df = pd.read_csv(min_prices_path)
    vendors_catalog_df = pd.read_csv(vendors_catalog_path)
    
    # Crear precio de venta en el catálogo de vendors con la fórmula corregida
    vendors_catalog_df['precio_vendedor'] = vendors_catalog_df['base_price'] + (vendors_catalog_df['base_price'] * vendors_catalog_df['percentage']/100)
    
    # Obtener precios mínimos únicos por producto
    min_prices_reference = min_prices_df[['super_catalog_id', 'precio_minimo']].drop_duplicates()
    
    # Unir con el catálogo de vendors
    df_comparacion = pd.merge(
        vendors_catalog_df,
        min_prices_reference,
        on='super_catalog_id',
        how='inner'
    )
    
    # Calcular diferencia porcentual
    df_comparacion['diferencia_porcentual'] = (
        (df_comparacion['precio_vendedor'] - df_comparacion['precio_minimo']) / 
        df_comparacion['precio_minimo'] * 100
    )
    
    # Agregar columna de diferencia absoluta
    df_comparacion['diferencia_absoluta'] = df_comparacion['diferencia_porcentual'].abs()
    
    # Categorizar las diferencias usando el valor absoluto
    def categorizar_diferencia(diferencia_abs):
        if diferencia_abs <= 5:
            return 'hasta_5_porciento'
        elif diferencia_abs <= 15:
            return 'hasta_15_porciento'
        else:
            return 'mayor_15_porciento'
    
    df_comparacion['categoria_diferencia'] = df_comparacion['diferencia_absoluta'].apply(categorizar_diferencia)
    
    # Crear resúmenes
    resumen_por_categoria = df_comparacion.groupby('categoria_diferencia').agg({
        'super_catalog_id': 'count',
        'vendor_id': lambda x: len(x.unique())
    }).reset_index()
    
    resumen_por_categoria.columns = [
        'categoria_diferencia',
        'cantidad_productos',
        'cantidad_vendors'
    ]
    
    resumen_por_vendor = df_comparacion.groupby(['vendor_id', 'categoria_diferencia']).agg({
        'super_catalog_id': 'count',
        'diferencia_porcentual': ['mean', 'min', 'max'],
        'diferencia_absoluta': 'mean'
    }).reset_index()
    
    resumen_por_vendor.columns = [
        'vendor_id',
        'categoria_diferencia',
        'cantidad_productos',
        'diferencia_promedio',
        'diferencia_minima',
        'diferencia_maxima',
        'diferencia_absoluta_promedio'
    ]
    
    # Identificar productos más representativos por categoría
    productos_representativos = df_comparacion.sort_values('diferencia_absoluta').groupby('categoria_diferencia').head(5)
    
    return {
        'detalle_completo': df_comparacion,
        'resumen_por_categoria': resumen_por_categoria,
        'resumen_por_vendor': resumen_por_vendor,
        'productos_representativos': productos_representativos[['super_catalog_id', 'vendor_id', 
                                                             'precio_vendedor', 'precio_minimo', 
                                                             'diferencia_porcentual', 'diferencia_absoluta',
                                                             'categoria_diferencia']]
    }

# Ejemplo de uso:
resultados = analyze_price_differences('vendors_catalog.csv', 'top_5_productos_geozona.csv')

# Mostrar resultados
display("\nResumen por categoría:")
display(resultados['resumen_por_categoria'])

display("\nEjemplos de productos representativos por categoría:")
for categoria in ['hasta_5_porciento', 'hasta_15_porciento', 'mayor_15_porciento']:
    display(f"\n{categoria}:")
    subset = resultados['productos_representativos'][
        resultados['productos_representativos']['categoria_diferencia'] == categoria
    ]
    display(subset[['super_catalog_id', 'vendor_id', 'precio_vendedor', 
                 'precio_minimo', 'diferencia_porcentual', 'diferencia_absoluta']])
# Out:
# '\nResumen por categoría:'
#   categoria_diferencia  cantidad_productos  cantidad_vendors
# 0   hasta_15_porciento                8435                15
# 1    hasta_5_porciento                5594                15
# 2   mayor_15_porciento               24888                16
# '\nEjemplos de productos representativos por categoría:'
# '\nhasta_5_porciento:'
#        super_catalog_id  vendor_id  precio_vendedor  precio_minimo  \
# 29558     7501563380224       1163            17.11          17.11
# 284       5391189220859       1156           756.24         756.24
# 290       7501082243376       1156          1998.20        1998.20
# 303       7501300421135       1156           236.25         236.25
# 5122       780083139759       1160            30.92          30.92
#
#        diferencia_porcentual  diferencia_absoluta
# 29558                    0.0                  0.0
# 284                      0.0                  0.0
# 290                      0.0                  0.0
# 303                      0.0                  0.0
# 5122                     0.0                  0.0
# '\nhasta_15_porciento:'
#       super_catalog_id  vendor_id  precio_vendedor  precio_minimo  \
# 257      7501298216812       1156      1054.060000        1109.54
# 403      7501298222424       1156       827.670000         871.24
# 6761     7501478315762       1161        34.986875          33.32
# 2606      759684031205       1151        14.430000          15.19
# 9518      759684031205       1151        14.430000          15.19
#
#       diferencia_porcentual  diferencia_absoluta
# 257               -5.000270             5.000270
# 403               -5.000918             5.000918
# 6761               5.002626             5.002626
# 2606              -5.003292             5.003292
# 9518              -5.003292             5.003292
# '\nmayor_15_porciento:'
#        super_catalog_id  vendor_id  precio_vendedor  precio_minimo  \
# 13908      780083149024       1152         29.41000          34.60
# 28889     7501075721256       1163         52.87000          62.20
# 30013     7501075721256       1163         52.87000          62.20
# 26613     7501349013223       1275         80.57985          94.80
# 11830     8027950210480       1152        579.47370         681.76
#
#        diferencia_porcentual  diferencia_absoluta
# 13908             -15.000000            15.000000
# 28889             -15.000000            15.000000
# 30013             -15.000000            15.000000
# 26613             -15.000158            15.000158
# 11830             -15.003271            15.003271

# %%
df_pedidos_proveedores_unique
# Out:
#        point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 0                  1238        8400005656               1.0          64.48
# 1                  1748        8400005656               1.0          48.79
# 2                  1291        8400005823               5.0          45.04
# 3                  1238       20800753067               4.0          78.48
# 4                  1679       20800753067               3.0          81.33
# ...                 ...               ...               ...            ...
# 85328              1824      891671002277               1.0         507.87
# 85329              2306      891671002277               1.0         579.88
# 85330              1320     9002240001022               2.0         113.15
# 85331              1311       93815704270               1.0         164.51
# 85332              1601       93815704270               1.0         164.51
#
#                geo_zone  vendor_id        name  base_price  percentage  \
# 0               Hidalgo       1161     Hidalgo     51.1182         0.0
# 1               Chiapas       1151     Chiapas     58.0300         0.0
# 2               Hidalgo       1161     Hidalgo     52.3506         0.0
# 3               Hidalgo       1161     Hidalgo     91.8182         0.0
# 4            Guanajuato       1161  Guanajuato     91.8182         0.0
# ...                 ...        ...         ...         ...         ...
# 85328           Durango       1156      México    534.6000         0.0
# 85329            Oaxaca       1156      México    534.6000         0.0
# 85330            Sonora       1156      México    110.0200         0.0
# 85331              CDMX       1159      México    189.1496         0.0
# 85332  Estado de México       1159      México    189.1496         0.0
#
#        precio_vendedor  precio_total_vendedor  status
# 0              51.1182                51.1182     1.0
# 1              58.0300                58.0300     NaN
# 2              52.3506               261.7530     0.0
# 3              91.8182               367.2728     1.0
# 4              91.8182               275.4546     NaN
# ...                ...                    ...     ...
# 85328         534.6000               534.6000     0.0
# 85329         534.6000               534.6000     NaN
# 85330         110.0200               220.0400     0.0
# 85331         189.1496               189.1496     NaN
# 85332         189.1496               189.1496     NaN
#
# [85333 rows x 12 columns]

# %%
df_pedidos_proveedores_unique[df_pedidos_proveedores_unique['super_catalog_id']==736085412734]
# Out:
#        point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 15103              1097      736085412734               1.0         667.67
# 15104              1097      736085412734               1.0         667.67
# 15105              1291      736085412734               1.0         643.29
# 15106              1291      736085412734               1.0         643.29
# 15107              1311      736085412734               1.0         643.29
# 15108              1311      736085412734               1.0         643.29
# 15109              1601      736085412734               2.0         643.29
# 15110              1601      736085412734               2.0         643.29
# 15111              1610      736085412734               1.0         670.86
# 15112              1610      736085412734               1.0         670.86
# 15113              1673      736085412734              34.0         634.00
# 15114              1673      736085412734              34.0         634.00
# 15115              1679      736085412734              12.0         632.21
# 15116              1679      736085412734              12.0         632.21
#
#                   geo_zone  vendor_id    name  base_price  percentage  \
# 15103  Baja California Sur       1156  México    733.2700         0.0
# 15104  Baja California Sur       1159  México    672.0576         0.0
# 15105              Hidalgo       1156  México    733.2700         0.0
# 15106              Hidalgo       1159  México    672.0576         0.0
# 15107                 CDMX       1156  México    733.2700         0.0
# 15108                 CDMX       1159  México    672.0576         0.0
# 15109     Estado de México       1156  México    733.2700         0.0
# 15110     Estado de México       1159  México    672.0576         0.0
# 15111           Nuevo León       1156  México    733.2700         0.0
# 15112           Nuevo León       1159  México    672.0576         0.0
# 15113            Michoacán       1156  México    733.2700         0.0
# 15114            Michoacán       1159  México    672.0576         0.0
# 15115           Guanajuato       1156  México    733.2700         0.0
# 15116           Guanajuato       1159  México    672.0576         0.0
#
#        precio_vendedor  precio_total_vendedor  status
# 15103         733.2700               733.2700     NaN
# 15104         672.0576               672.0576     NaN
# 15105         733.2700               733.2700     2.0
# 15106         672.0576               672.0576     1.0
# 15107         733.2700               733.2700     NaN
# 15108         672.0576               672.0576     NaN
# 15109         733.2700              1466.5400     NaN
# 15110         672.0576              1344.1152     NaN
# 15111         733.2700               733.2700     NaN
# 15112         672.0576               672.0576     1.0
# 15113         733.2700             24931.1800     NaN
# 15114         672.0576             22849.9584     NaN
# 15115         733.2700              8799.2400     NaN
# 15116         672.0576              8064.6912     NaN

# %%
df_pedidos_proveedores_unique[df_pedidos_proveedores_unique['precio_vendedor']<df_pedidos_proveedores_unique['precio_minimo']]['super_catalog_id'].nunique()
# Out:
# 4346

# %%
df_pedidos_proveedores_unique['point_of_sale_id']
# Out:
# 0        1238
# 1        1748
# 2        1291
# 3        1238
# 4        1679
#          ...
# 85328    1824
# 85329    2306
# 85330    1320
# 85331    1311
# 85332    1601
# Name: point_of_sale_id, Length: 85333, dtype: int64

# %%
min_prices = (df_pedidos_proveedores_unique
              .groupby(['point_of_sale_id', 'super_catalog_id'])['precio_minimo']
              .min()
              .reset_index())
min_prices.columns = ['point_of_sale_id', 'super_catalog_id', 'precio_minimo_orders']

# 2. Hacer el merge por ambas columnas
df_precios_comparados = pd.merge(
    df_pedidos_proveedores_unique,
    min_prices,
    on=['point_of_sale_id', 'super_catalog_id'],
    how='inner'
)

# 3. Calcular diferencia porcentual
df_precios_comparados['diferencia_porcentual'] = (
    (df_precios_comparados['precio_vendedor'].astype(float) - 
     df_precios_comparados['precio_minimo_orders'].astype(float)) / 
    df_precios_comparados['precio_minimo_orders'].astype(float) * 100
)

# 4. Mantener el resto del código igual para la categorización
def categorizar_diferencia(diferencia):
    if 0 < diferencia <= 5:
        return 'hasta_5_porciento'
    elif 5 < diferencia <= 15:
        return 'hasta_15_porciento'
    else:
        return 'mayor_15_porciento'

df_precios_comparados['categoria_diferencia'] = df_precios_comparados['diferencia_porcentual'].apply(categorizar_diferencia)

# 5. Crear el dataframe final
df_analisis_precios = df_precios_comparados[[
    'super_catalog_id',
    'point_of_sale_id',
    'vendor_id',
    'precio_vendedor',
    'precio_minimo_orders',
    'diferencia_porcentual',
    'categoria_diferencia',
    'unidades_pedidas',
    'geo_zone'
]].copy()

# %%
min_prices[min_prices['super_catalog_id'] == 736085412734]
# Out:
#        point_of_sale_id  super_catalog_id  precio_minimo_orders
# 568                1097      736085412734                667.67
# 7728               1291      736085412734                643.29
# 8639               1311      736085412734                643.29
# 16991              1601      736085412734                643.29
# 18167              1610      736085412734                670.86
# 20550              1673      736085412734                634.00
# 22229              1679      736085412734                632.21

# %%
df_analisis_precios[df_analisis_precios['super_catalog_id']==736085412734]
# Out:
#        super_catalog_id  point_of_sale_id  vendor_id  precio_vendedor  \
# 15103      736085412734              1097       1156         733.2700
# 15104      736085412734              1097       1159         672.0576
# 15105      736085412734              1291       1156         733.2700
# 15106      736085412734              1291       1159         672.0576
# 15107      736085412734              1311       1156         733.2700
# 15108      736085412734              1311       1159         672.0576
# 15109      736085412734              1601       1156         733.2700
# 15110      736085412734              1601       1159         672.0576
# 15111      736085412734              1610       1156         733.2700
# 15112      736085412734              1610       1159         672.0576
# 15113      736085412734              1673       1156         733.2700
# 15114      736085412734              1673       1159         672.0576
# 15115      736085412734              1679       1156         733.2700
# 15116      736085412734              1679       1159         672.0576
#
#        precio_minimo_orders  diferencia_porcentual categoria_diferencia  \
# 15103                667.67               9.825213   hasta_15_porciento
# 15104                667.67               0.657151    hasta_5_porciento
# 15105                643.29              13.987471   hasta_15_porciento
# 15106                643.29               4.471949    hasta_5_porciento
# 15107                643.29              13.987471   hasta_15_porciento
# 15108                643.29               4.471949    hasta_5_porciento
# 15109                643.29              13.987471   hasta_15_porciento
# 15110                643.29               4.471949    hasta_5_porciento
# 15111                670.86               9.302984   hasta_15_porciento
# 15112                670.86               0.178517    hasta_5_porciento
# 15113                634.00              15.657729   mayor_15_porciento
# 15114                634.00               6.002776   hasta_15_porciento
# 15115                632.21              15.985195   mayor_15_porciento
# 15116                632.21               6.302906   hasta_15_porciento
#
#        unidades_pedidas             geo_zone
# 15103               1.0  Baja California Sur
# 15104               1.0  Baja California Sur
# 15105               1.0              Hidalgo
# 15106               1.0              Hidalgo
# 15107               1.0                 CDMX
# 15108               1.0                 CDMX
# 15109               2.0     Estado de México
# 15110               2.0     Estado de México
# 15111               1.0           Nuevo León
# 15112               1.0           Nuevo León
# 15113              34.0            Michoacán
# 15114              34.0            Michoacán
# 15115              12.0           Guanajuato
# 15116              12.0           Guanajuato

# %%
df_analisis_precios[df_analisis_precios['super_catalog_id']==736085412734]
# Out:
#        super_catalog_id  point_of_sale_id  vendor_id  precio_vendedor  \
# 15103      736085412734              1097       1156         733.2700
# 15104      736085412734              1097       1159         672.0576
# 15105      736085412734              1291       1156         733.2700
# 15106      736085412734              1291       1159         672.0576
# 15107      736085412734              1311       1156         733.2700
# 15108      736085412734              1311       1159         672.0576
# 15109      736085412734              1601       1156         733.2700
# 15110      736085412734              1601       1159         672.0576
# 15111      736085412734              1610       1156         733.2700
# 15112      736085412734              1610       1159         672.0576
# 15113      736085412734              1673       1156         733.2700
# 15114      736085412734              1673       1159         672.0576
# 15115      736085412734              1679       1156         733.2700
# 15116      736085412734              1679       1159         672.0576
#
#        precio_minimo_orders  diferencia_porcentual categoria_diferencia  \
# 15103                667.67               9.825213   hasta_15_porciento
# 15104                667.67               0.657151    hasta_5_porciento
# 15105                643.29              13.987471   hasta_15_porciento
# 15106                643.29               4.471949    hasta_5_porciento
# 15107                643.29              13.987471   hasta_15_porciento
# 15108                643.29               4.471949    hasta_5_porciento
# 15109                643.29              13.987471   hasta_15_porciento
# 15110                643.29               4.471949    hasta_5_porciento
# 15111                670.86               9.302984   hasta_15_porciento
# 15112                670.86               0.178517    hasta_5_porciento
# 15113                634.00              15.657729   mayor_15_porciento
# 15114                634.00               6.002776   hasta_15_porciento
# 15115                632.21              15.985195   mayor_15_porciento
# 15116                632.21               6.302906   hasta_15_porciento
#
#        unidades_pedidas             geo_zone
# 15103               1.0  Baja California Sur
# 15104               1.0  Baja California Sur
# 15105               1.0              Hidalgo
# 15106               1.0              Hidalgo
# 15107               1.0                 CDMX
# 15108               1.0                 CDMX
# 15109               2.0     Estado de México
# 15110               2.0     Estado de México
# 15111               1.0           Nuevo León
# 15112               1.0           Nuevo León
# 15113              34.0            Michoacán
# 15114              34.0            Michoacán
# 15115              12.0           Guanajuato
# 15116              12.0           Guanajuato

# %%
df_analisis_precios.to_csv('productos_clasificados_test.csv',index=False, encoding='utf-8')

# %%
df_analisis_precios['vendor_id'].value_counts()
# Out:
# vendor_id
# 1156    24243
# 1152    18646
# 1159    12191
# 1150    10021
# 1275     6775
# 1164     4669
# 1161     2841
# 1373     2133
# 1303     1077
# 1163      967
# 1151      647
# 1160      588
# 1153      509
# 1141       19
# 1157        7
# Name: count, dtype: int64

# %%
min_prices[min_prices['super_catalog_id'] ==736085412734]
# Out:
#        point_of_sale_id  super_catalog_id  precio_minimo_orders
# 568                1097      736085412734                667.67
# 7728               1291      736085412734                643.29
# 8639               1311      736085412734                643.29
# 16991              1601      736085412734                643.29
# 18167              1610      736085412734                670.86
# 20550              1673      736085412734                634.00
# 22229              1679      736085412734                632.21

# %%
min_prices
# Out:
#        point_of_sale_id  super_catalog_id  precio_minimo_orders
# 0                   721          75014032                 90.24
# 1                   721          75050733                 78.07
# 2                   721          75050764                 41.14
# 3                   721          78924345                 26.72
# 4                   721      650240006647                108.13
# ...                 ...               ...                   ...
# 38089              2343     7702031244493                 39.57
# 38090              2343     7702031887928                 51.47
# 38091              2343     7702035433299                 51.47
# 38092              2343     7702035469151                 27.07
# 38093              2343     7794640660627                 69.06
#
# [38094 rows x 3 columns]

# %%
def clasificar_productos(df_analisis_precios):
    """
    Clasifica los productos en tres categorías basadas en su diferencia porcentual de precio
    y genera resúmenes estadísticos.
    
    Args:
        df_analisis_precios (pd.DataFrame): DataFrame con el análisis de precios original
        
    Returns:
        tuple: (df_productos_clasificados, resumen_clasificacion, resumen_vendor_clasificacion)
    """
    # 1. Primero creamos los subsets por categoría
    productos_5_porciento = df_analisis_precios[
        df_analisis_precios['categoria_diferencia'] == 'hasta_5_porciento'
    ].copy()

    productos_15_porciento = df_analisis_precios[
        df_analisis_precios['categoria_diferencia'] == 'hasta_15_porciento'
    ].copy()

    productos_mayor_15 = df_analisis_precios[
        df_analisis_precios['categoria_diferencia'] == 'mayor_15_porciento'
    ].copy()

    # 2. Añadimos la nueva clasificación a cada subset
    productos_5_porciento['clasificacion_producto'] = 'Producto Ganador'
    productos_15_porciento['clasificacion_producto'] = 'Producto Medianamente Ganador'
    productos_mayor_15['clasificacion_producto'] = 'Producto No Ganador'

    # 3. Concatenamos los DataFrames
    df_productos_clasificados = pd.concat([
        productos_5_porciento,
        productos_15_porciento,
        productos_mayor_15
    ], ignore_index=True)

    # 4. Reordenamos las columnas para mejor visualización
    columnas_orden = [
        'super_catalog_id',
        'point_of_sale_id',
        'vendor_id',
        'clasificacion_producto',
        'categoria_diferencia',
        'diferencia_porcentual',
        'precio_vendedor',
        'precio_minimo_orders',
        'unidades_pedidas',
        'geo_zone'
    ]

    df_productos_clasificados = df_productos_clasificados[columnas_orden]

    # 5. Agregamos algunos resúmenes útiles
    display("\nResumen de productos por clasificación:")
    resumen_clasificacion = df_productos_clasificados.groupby('clasificacion_producto').agg({
        'super_catalog_id': 'count',
        'diferencia_porcentual': ['mean', 'min', 'max'],
        'unidades_pedidas': 'sum'
    }).round(2)

    display("\nResumen por vendor y clasificación:")
    resumen_vendor_clasificacion = df_productos_clasificados.groupby(
        ['vendor_id', 'clasificacion_producto']
    ).agg({
        'super_catalog_id': 'count',
        'diferencia_porcentual': 'mean',
        'unidades_pedidas': 'sum'
    }).round(2)

    # 6. Exportamos el DataFrame clasificado a CSV
    #df_productos_clasificados.to_csv('productos_clasificados.csv', index=False, encoding='utf-8')
    display("\nArchivo 'productos_clasificados.csv' ha sido creado exitosamente.")
    
    return df_productos_clasificados, resumen_clasificacion, resumen_vendor_clasificacion

# %%
clasificar_productos(df_analisis_precios)
# Out:
# '\nResumen de productos por clasificación:'
# '\nResumen por vendor y clasificación:'
# "\nArchivo 'productos_clasificados.csv' ha sido creado exitosamente."
# (       super_catalog_id  point_of_sale_id  vendor_id clasificacion_producto  \
#  0           20800753067              1477       1303       Producto Ganador
#  1          637420200804              1601       1161       Producto Ganador
#  2          637420200804              1601       1163       Producto Ganador
#  3          637420200897              1601       1161       Producto Ganador
#  4          637420200897              1601       1163       Producto Ganador
#  ...                 ...               ...        ...                    ...
#  85328      891671002277              1575       1156    Producto No Ganador
#  85329      891671002277              1679       1156    Producto No Ganador
#  85330      891671002277              1720       1156    Producto No Ganador
#  85331      891671002277              2306       1156    Producto No Ganador
#  85332     9002240001022              1320       1156    Producto No Ganador
#
#        categoria_diferencia  diferencia_porcentual  precio_vendedor  \
#  0        hasta_5_porciento               3.650013          80.0800
#  1        hasta_5_porciento               3.896175          38.0260
#  2        hasta_5_porciento               1.256831          37.0600
#  3        hasta_5_porciento               3.882778          40.2338
#  4        hasta_5_porciento               1.265169          39.2200
#  ...                    ...                    ...              ...
#  85328   mayor_15_porciento              -5.704307         534.6000
#  85329   mayor_15_porciento              -5.704307         534.6000
#  85330   mayor_15_porciento              -5.704307         534.6000
#  85331   mayor_15_porciento              -7.808512         534.6000
#  85332   mayor_15_porciento              -2.766240         110.0200
#
#         precio_minimo_orders  unidades_pedidas          geo_zone
#  0                     77.26               2.0  Estado de México
#  1                     36.60               2.0  Estado de México
#  2                     36.60               2.0  Estado de México
#  3                     38.73               1.0  Estado de México
#  4                     38.73               1.0  Estado de México
#  ...                     ...               ...               ...
#  85328                566.94               2.0    Aguascalientes
#  85329                566.94              13.0        Guanajuato
#  85330                566.94               2.0        Tamaulipas
#  85331                579.88               1.0            Oaxaca
#  85332                113.15               2.0            Sonora
#
#  [85333 rows x 10 columns],
#                                super_catalog_id diferencia_porcentual         \
#                                           count                  mean    min
#  clasificacion_producto
#  Producto Ganador                         10809                  2.36   0.00
#  Producto Medianamente Ganador            20854                  9.91   5.00
#  Producto No Ganador                      53670                 15.01 -97.17
#
#                                          unidades_pedidas
#                                      max              sum
#  clasificacion_producto
#  Producto Ganador                   5.00         125645.0
#  Producto Medianamente Ganador     15.00         332592.0
#  Producto No Ganador            20558.11        1166330.0  ,
#                                           super_catalog_id  \
#  vendor_id clasificacion_producto
#  1141      Producto Ganador                              1
#            Producto Medianamente Ganador                 4
#            Producto No Ganador                          14
#  1150      Producto Ganador                            482
#            Producto Medianamente Ganador              2702
#            Producto No Ganador                        6837
#  1151      Producto Ganador                             27
#            Producto Medianamente Ganador               109
#            Producto No Ganador                         511
#  1152      Producto Ganador                           3692
#            Producto Medianamente Ganador              3884
#            Producto No Ganador                       11070
#  1153      Producto Ganador                             13
#            Producto Medianamente Ganador                23
#            Producto No Ganador                         473
#  1156      Producto Ganador                           4003
#            Producto Medianamente Ganador              7669
#            Producto No Ganador                       12571
#  1157      Producto No Ganador                           7
#  1159      Producto Ganador                            872
#            Producto Medianamente Ganador              2301
#            Producto No Ganador                        9018
#  1160      Producto Ganador                             65
#            Producto Medianamente Ganador               148
#            Producto No Ganador                         375
#  1161      Producto Ganador                            156
#            Producto Medianamente Ganador               665
#            Producto No Ganador                        2020
#  1163      Producto Ganador                             78
#            Producto Medianamente Ganador               345
#            Producto No Ganador                         544
#  1164      Producto Ganador                            657
#            Producto Medianamente Ganador               662
#            Producto No Ganador                        3350
#  1275      Producto Ganador                            544
#            Producto Medianamente Ganador              1883
#            Producto No Ganador                        4348
#  1303      Producto Ganador                            195
#            Producto Medianamente Ganador               332
#            Producto No Ganador                         550
#  1373      Producto Ganador                             24
#            Producto Medianamente Ganador               127
#            Producto No Ganador                        1982
#
#                                           diferencia_porcentual  \
#  vendor_id clasificacion_producto
#  1141      Producto Ganador                                3.64
#            Producto Medianamente Ganador                   9.83
#            Producto No Ganador                            24.72
#  1150      Producto Ganador                                2.50
#            Producto Medianamente Ganador                  10.78
#            Producto No Ganador                            28.48
#  1151      Producto Ganador                                2.93
#            Producto Medianamente Ganador                  11.03
#            Producto No Ganador                            28.13
#  1152      Producto Ganador                                2.19
#            Producto Medianamente Ganador                   9.05
#            Producto No Ganador                            -3.44
#  1153      Producto Ganador                                2.80
#            Producto Medianamente Ganador                  10.26
#            Producto No Ganador                           -25.48
#  1156      Producto Ganador                                2.37
#            Producto Medianamente Ganador                   9.74
#            Producto No Ganador                            23.12
#  1157      Producto No Ganador                             3.60
#  1159      Producto Ganador                                2.46
#            Producto Medianamente Ganador                  10.70
#            Producto No Ganador                            21.67
#  1160      Producto Ganador                                2.58
#            Producto Medianamente Ganador                  10.35
#            Producto No Ganador                             8.18
#  1161      Producto Ganador                                2.73
#            Producto Medianamente Ganador                  10.68
#            Producto No Ganador                            16.55
#  1163      Producto Ganador                                2.71
#            Producto Medianamente Ganador                  10.47
#            Producto No Ganador                            39.37
#  1164      Producto Ganador                                2.42
#            Producto Medianamente Ganador                   9.04
#            Producto No Ganador                            -8.01
#  1275      Producto Ganador                                2.74
#            Producto Medianamente Ganador                  10.02
#            Producto No Ganador                            15.38
#  1303      Producto Ganador                                2.63
#            Producto Medianamente Ganador                   9.74
#            Producto No Ganador                             2.70
#  1373      Producto Ganador                                2.65
#            Producto Medianamente Ganador                  10.45
#            Producto No Ganador                            30.67
#
#                                           unidades_pedidas
#  vendor_id clasificacion_producto
#  1141      Producto Ganador                            2.0
#            Producto Medianamente Ganador              14.0
#            Producto No Ganador                        27.0
#  1150      Producto Ganador                         3627.0
#            Producto Medianamente Ganador           42758.0
#            Producto No Ganador                    281351.0
#  1151      Producto Ganador                          122.0
#            Producto Medianamente Ganador             900.0
#            Producto No Ganador                      6446.0
#  1152      Producto Ganador                        75896.0
#            Producto Medianamente Ganador          152519.0
#            Producto No Ganador                    259346.0
#  1153      Producto Ganador                          173.0
#            Producto Medianamente Ganador             414.0
#            Producto No Ganador                      4046.0
#  1156      Producto Ganador                        23367.0
#            Producto Medianamente Ganador           49512.0
#            Producto No Ganador                    105461.0
#  1157      Producto No Ganador                       112.0
#  1159      Producto Ganador                         4841.0
#            Producto Medianamente Ganador           17994.0
#            Producto No Ganador                    251865.0
#  1160      Producto Ganador                          544.0
#            Producto Medianamente Ganador            2540.0
#            Producto No Ganador                      4477.0
#  1161      Producto Ganador                         2225.0
#            Producto Medianamente Ganador            6217.0
#            Producto No Ganador                     21924.0
#  1163      Producto Ganador                          594.0
#            Producto Medianamente Ganador            3187.0
#            Producto No Ganador                      6246.0
#  1164      Producto Ganador                         7069.0
#            Producto Medianamente Ganador           11073.0
#            Producto No Ganador                     40302.0
#  1275      Producto Ganador                         5620.0
#            Producto Medianamente Ganador           41335.0
#            Producto No Ganador                    159389.0
#  1303      Producto Ganador                         1450.0
#            Producto Medianamente Ganador            3673.0
#            Producto No Ganador                      6741.0
#  1373      Producto Ganador                          115.0
#            Producto Medianamente Ganador             456.0
#            Producto No Ganador                     18597.0  )

# %%
import pandas as pd

# %%
semi_ganadores = pd.read_csv('productos_clasificados.csv')
semi_ganadores['precio_vendedor_total'] = semi_ganadores['precio_vendedor']*semi_ganadores['unidades_pedidas']

# %%
semi_ganadores[semi_ganadores['super_catalog_id']==7501943474895]
# Out:
#        super_catalog_id  point_of_sale_id  vendor_id  \
# 7670      7501943474895               725       1152
# 7671      7501943474895              1170       1156
# 7672      7501943474895              1824       1156
# 7673      7501943474895              1824       1152
# 7674      7501943474895              2089       1156
# 7675      7501943474895              2136       1152
# 25501     7501943474895               725       1156
# 25502     7501943474895              1422       1156
# 25503     7501943474895              1422       1152
# 25504     7501943474895              2136       1156
# 34561     7501943474895              2136       1373
# 69489     7501943474895              1170       1152
# 69490     7501943474895              1448       1156
# 69491     7501943474895              1448       1152
# 69492     7501943474895              1741       1156
# 69493     7501943474895              1741       1152
# 69494     7501943474895              2089       1152
# 69495     7501943474895              2138       1156
# 69496     7501943474895              2138       1152
#
#               clasificacion_producto categoria_diferencia  \
# 7670                Producto Ganador    hasta_5_porciento
# 7671                Producto Ganador    hasta_5_porciento
# 7672                Producto Ganador    hasta_5_porciento
# 7673                Producto Ganador    hasta_5_porciento
# 7674                Producto Ganador    hasta_5_porciento
# 7675                Producto Ganador    hasta_5_porciento
# 25501  Producto Medianamente Ganador   hasta_15_porciento
# 25502  Producto Medianamente Ganador   hasta_15_porciento
# 25503  Producto Medianamente Ganador   hasta_15_porciento
# 25504  Producto Medianamente Ganador   hasta_15_porciento
# 34561            Producto No Ganador   mayor_15_porciento
# 69489            Producto No Ganador   mayor_15_porciento
# 69490            Producto No Ganador   mayor_15_porciento
# 69491            Producto No Ganador   mayor_15_porciento
# 69492            Producto No Ganador   mayor_15_porciento
# 69493            Producto No Ganador   mayor_15_porciento
# 69494            Producto No Ganador   mayor_15_porciento
# 69495            Producto No Ganador   mayor_15_porciento
# 69496            Producto No Ganador   mayor_15_porciento
#
#        diferencia_porcentual  precio_vendedor  precio_minimo_orders  \
# 7670                3.085200          65.8199                 63.85
# 7671                1.975084          67.1200                 65.82
# 7672                4.597164          67.1200                 64.17
# 7673                2.571139          65.8199                 64.17
# 7674                1.975084          67.1200                 65.82
# 7675                3.085200          65.8199                 63.85
# 25501               5.121378          67.1200                 63.85
# 25502               7.840617          67.1200                 62.24
# 25503               5.751767          65.8199                 62.24
# 25504               5.121378          67.1200                 63.85
# 34561              51.996868          97.0500                 63.85
# 69489              -0.000152          65.8199                 65.82
# 69490              27.459172          67.1200                 52.66
# 69491              24.990315          65.8199                 52.66
# 69492              -5.584470          67.1200                 71.09
# 69493              -7.413279          65.8199                 71.09
# 69494              -0.000152          65.8199                 65.82
# 69495              27.459172          67.1200                 52.66
# 69496              24.990315          65.8199                 52.66
#
#        unidades_pedidas              geo_zone  precio_vendedor_total
# 7670                2.0                  CDMX               131.6398
# 7671                8.0               Hidalgo               536.9600
# 7672                2.0               Durango               134.2400
# 7673                2.0               Durango               131.6398
# 7674               12.0  Coahuila de Zaragoza               805.4400
# 7675                3.0      Estado de México               197.4597
# 25501               2.0                  CDMX               134.2400
# 25502               4.0             Querétaro               268.4800
# 25503               4.0             Querétaro               263.2796
# 25504               3.0      Estado de México               201.3600
# 34561               3.0      Estado de México               291.1500
# 69489               8.0               Hidalgo               526.5592
# 69490               6.0               Sinaloa               402.7200
# 69491               6.0               Sinaloa               394.9194
# 69492               8.0               Chiapas               536.9600
# 69493               8.0               Chiapas               526.5592
# 69494              12.0  Coahuila de Zaragoza               789.8388
# 69495               2.0               Jalisco               134.2400
# 69496               2.0               Jalisco               131.6398

# %%
winners = pd.read_csv('top_5_productos_geozona.csv')

# %%
winners[winners['vendor_id']==1156]['super_catalog_id'].nunique()
# Out:
# 628

# %%
winners[winners['vendor_id']==1152]['super_catalog_id'].nunique()
# Out:
# 2259

# %%
orders
# Out:
#        point_of_sale_id  super_catalog_id  order_id           order_date  \
# 0                  1182          75000950    239442  2025-01-16 02:27:02
# 1                  1182          75001865    244731  2025-01-30 01:21:43
# 2                  1182          75001872    245977  2025-02-03 00:02:51
# 3                  1182          75002794    239442  2025-01-16 02:27:02
# 4                  1182          75006433    237002  2025-01-09 03:54:07
# ...                 ...               ...       ...                  ...
# 82231              2312     7502216792920    236410  2025-01-07 21:46:02
# 82232              2312     7502227427392    236410  2025-01-07 21:46:02
# 82233              2174     7502009744129    247585  2025-02-06 18:35:52
# 82234              2174     7503003738879    247573  2025-02-06 18:18:06
# 82235              2175     7502208891228    249471  2025-02-11 20:37:42
#
#        unidades_pedidas  precio_minimo  vendor_id  valor_vendedor  \
# 0                  12.0         14.820         11          177.84
# 1                   5.0         42.710         11          213.55
# 2                   6.0         27.040         11          162.24
# 3                   6.0         25.640         11          153.84
# 4                  10.0         12.590         34          125.90
# ...                 ...            ...        ...             ...
# 82231              40.0         45.510         24         1820.40
# 82232              20.0         18.030         42          360.60
# 82233             200.0         35.350      10277         7070.00
# 82234             300.0         22.860      10277         6858.00
# 82235            1000.0         14.599      10267        14599.00
#
#                geo_zone country
# 0                  CDMX      MX
# 1                  CDMX      MX
# 2                  CDMX      MX
# 3                  CDMX      MX
# 4                  CDMX      MX
# ...                 ...     ...
# 82231         Michoacán      MX
# 82232         Michoacán      MX
# 82233  Estado de México      MX
# 82234  Estado de México      MX
# 82235           Jalisco      MX
#
# [82236 rows x 10 columns]

# %%
top
# Out:
#       point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 0                 1575     7501300409911               3.0         508.20
# 1                 1575     7501314702756               2.0         528.62
# 2                 1575      891671002277               2.0         566.94
# 3                 1575     7501033920332               1.0         989.50
# 4                 1575     7501314701650               1.0         688.59
# ...                ...               ...               ...            ...
# 4154              2308     7501349020122               1.0          27.63
# 4155              2308     7501349021747               1.0          15.55
# 4156              2308     7501349011984               1.0          14.88
# 4157              2308     7501349011618               1.0          14.88
# 4158              2308     7501349029071               1.0          14.88
#
#             geo_zone  vendor_id            name  base_price  percentage  \
# 0     Aguascalientes       1141  Aguascalientes    508.2000        -0.1
# 1     Aguascalientes       1156          México    524.4000         0.0
# 2     Aguascalientes       1159          México    507.3840         0.0
# 3     Aguascalientes       1159          México    709.5024         0.0
# 4     Aguascalientes       1156          México    683.1000         0.0
# ...              ...        ...             ...         ...         ...
# 4154         Yucatán       1152          México     25.0830         0.0
# 4155         Yucatán       1152          México     14.0698         0.0
# 4156         Yucatán       1152          México     13.2138         0.0
# 4157         Yucatán       1152          México     12.7239         0.0
# 4158         Yucatán       1152          México     12.5415         0.0
#
#       precio_vendedor  precio_total_vendedor  status  valor_total_vendedor
# 0            507.6918              1523.0754     NaN             1523.0754
# 1            524.4000              1048.8000     0.0             1048.8000
# 2            507.3840              1014.7680     1.0             1014.7680
# 3            709.5024               709.5024     1.0              709.5024
# 4            683.1000               683.1000     0.0              683.1000
# ...               ...                    ...     ...                   ...
# 4154          25.0830                25.0830     1.0               25.0830
# 4155          14.0698                14.0698     1.0               14.0698
# 4156          13.2138                13.2138     1.0               13.2138
# 4157          12.7239                12.7239     1.0               12.7239
# 4158          12.5415                12.5415     1.0               12.5415
#
# [4159 rows x 13 columns]

# %%
top['precio_total_droguería']=top['unidades_pedidas']*top['precio_minimo']

# %%
top
# Out:
#       point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 0                 1575     7501300409911               3.0         508.20
# 1                 1575     7501314702756               2.0         528.62
# 2                 1575      891671002277               2.0         566.94
# 3                 1575     7501033920332               1.0         989.50
# 4                 1575     7501314701650               1.0         688.59
# ...                ...               ...               ...            ...
# 4154              2308     7501349020122               1.0          27.63
# 4155              2308     7501349021747               1.0          15.55
# 4156              2308     7501349011984               1.0          14.88
# 4157              2308     7501349011618               1.0          14.88
# 4158              2308     7501349029071               1.0          14.88
#
#             geo_zone  vendor_id            name  base_price  percentage  \
# 0     Aguascalientes       1141  Aguascalientes    508.2000        -0.1
# 1     Aguascalientes       1156          México    524.4000         0.0
# 2     Aguascalientes       1159          México    507.3840         0.0
# 3     Aguascalientes       1159          México    709.5024         0.0
# 4     Aguascalientes       1156          México    683.1000         0.0
# ...              ...        ...             ...         ...         ...
# 4154         Yucatán       1152          México     25.0830         0.0
# 4155         Yucatán       1152          México     14.0698         0.0
# 4156         Yucatán       1152          México     13.2138         0.0
# 4157         Yucatán       1152          México     12.7239         0.0
# 4158         Yucatán       1152          México     12.5415         0.0
#
#       precio_vendedor  precio_total_vendedor  status  valor_total_vendedor  \
# 0            507.6918              1523.0754     NaN             1523.0754
# 1            524.4000              1048.8000     0.0             1048.8000
# 2            507.3840              1014.7680     1.0             1014.7680
# 3            709.5024               709.5024     1.0              709.5024
# 4            683.1000               683.1000     0.0              683.1000
# ...               ...                    ...     ...                   ...
# 4154          25.0830                25.0830     1.0               25.0830
# 4155          14.0698                14.0698     1.0               14.0698
# 4156          13.2138                13.2138     1.0               13.2138
# 4157          12.7239                12.7239     1.0               12.7239
# 4158          12.5415                12.5415     1.0               12.5415
#
#       precio_total_droguería
# 0                    1524.60
# 1                    1057.24
# 2                    1133.88
# 3                     989.50
# 4                     688.59
# ...                      ...
# 4154                   27.63
# 4155                   15.55
# 4156                   14.88
# 4157                   14.88
# 4158                   14.88
#
# [4159 rows x 14 columns]

# %%
top[top['point_of_sale_id']==1679]['precio_total_droguería'].sum()
# Out:
# np.float64(932865.37)

# %%
top[top['precio_minimo']<top['precio_vendedor']]
# Out:
# Empty DataFrame
# Columns: [point_of_sale_id, super_catalog_id, unidades_pedidas, precio_minimo, geo_zone, vendor_id, name, base_price, percentage, precio_vendedor, precio_total_vendedor, status, valor_total_vendedor, precio_total_droguería]
# Index: []

# %%
orders_1192 = orders[orders['point_of_sale_id']==1650]

# %%
top
# Out:
#       point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 0                 1575     7501300409911               3.0         508.20
# 1                 1575     7501314702756               2.0         528.62
# 2                 1575      891671002277               2.0         566.94
# 3                 1575     7501033920332               1.0         989.50
# 4                 1575     7501314701650               1.0         688.59
# ...                ...               ...               ...            ...
# 4154              2308     7501349020122               1.0          27.63
# 4155              2308     7501349021747               1.0          15.55
# 4156              2308     7501349011984               1.0          14.88
# 4157              2308     7501349011618               1.0          14.88
# 4158              2308     7501349029071               1.0          14.88
#
#             geo_zone  vendor_id            name  base_price  percentage  \
# 0     Aguascalientes       1141  Aguascalientes    508.2000        -0.1
# 1     Aguascalientes       1156          México    524.4000         0.0
# 2     Aguascalientes       1159          México    507.3840         0.0
# 3     Aguascalientes       1159          México    709.5024         0.0
# 4     Aguascalientes       1156          México    683.1000         0.0
# ...              ...        ...             ...         ...         ...
# 4154         Yucatán       1152          México     25.0830         0.0
# 4155         Yucatán       1152          México     14.0698         0.0
# 4156         Yucatán       1152          México     13.2138         0.0
# 4157         Yucatán       1152          México     12.7239         0.0
# 4158         Yucatán       1152          México     12.5415         0.0
#
#       precio_vendedor  precio_total_vendedor  status  valor_total_vendedor  \
# 0            507.6918              1523.0754     NaN             1523.0754
# 1            524.4000              1048.8000     0.0             1048.8000
# 2            507.3840              1014.7680     1.0             1014.7680
# 3            709.5024               709.5024     1.0              709.5024
# 4            683.1000               683.1000     0.0              683.1000
# ...               ...                    ...     ...                   ...
# 4154          25.0830                25.0830     1.0               25.0830
# 4155          14.0698                14.0698     1.0               14.0698
# 4156          13.2138                13.2138     1.0               13.2138
# 4157          12.7239                12.7239     1.0               12.7239
# 4158          12.5415                12.5415     1.0               12.5415
#
#       precio_total_droguería
# 0                    1524.60
# 1                    1057.24
# 2                    1133.88
# 3                     989.50
# 4                     688.59
# ...                      ...
# 4154                   27.63
# 4155                   15.55
# 4156                   14.88
# 4157                   14.88
# 4158                   14.88
#
# [4159 rows x 14 columns]

# %%
interseccion = pd.merge(top,orders_1192, on=['super_catalog_id', 'point_of_sale_id'], how='inner')

# %%
interseccion
# Out:
#    point_of_sale_id  super_catalog_id  unidades_pedidas_x  precio_minimo_x  \
# 0              1650     7590002037157                20.0          127.530
# 1              1650      714908101065                20.0           53.190
# 2              1650     7501022150221                50.0           17.700
# 3              1650     7501089804310                 2.0          389.610
# 4              1650     7501590210075                 4.0           48.000
# 5              1650     7501130742493                 4.0           34.719
# 6              1650     7501565606100                 4.0           23.580
# 7              1650     7503003406785                 4.0           14.780
#
#   geo_zone_x  vendor_id_x     name  base_price  percentage  precio_vendedor  \
# 0    Chiapas         1164   México    124.0000        0.00       124.000000
# 1    Chiapas         1152   México     52.9383        0.00        52.938300
# 2    Chiapas         1150   México     17.0085       -0.05        16.999996
# 3    Chiapas         1151  Chiapas    359.0200        0.00       359.020000
# 4    Chiapas         1152   México     47.0562        0.00        47.056200
# 5    Chiapas         1152   México     34.7185        0.00        34.718500
# 6    Chiapas         1151  Chiapas     20.1800        0.00        20.180000
# 7    Chiapas         1152   México     13.4137        0.00        13.413700
#
#    ...  valor_total_vendedor  precio_total_droguería  order_id  \
# 0  ...           2480.000000                2550.600    237176
# 1  ...           1058.766000                1063.800    237176
# 2  ...            849.999788                 885.000    237176
# 3  ...            718.040000                 779.220    237176
# 4  ...            188.224800                 192.000    237176
# 5  ...            138.874000                 138.876    237176
# 6  ...             80.720000                  94.320    237176
# 7  ...             53.654800                  59.120    237176
#
#             order_date  unidades_pedidas_y precio_minimo_y  vendor_id_y  \
# 0  2025-01-09 20:38:18                20.0         127.530           11
# 1  2025-01-09 20:38:18                20.0          53.190           34
# 2  2025-01-09 20:38:18                50.0          17.700        10021
# 3  2025-01-09 20:38:18                 2.0         389.610        10021
# 4  2025-01-09 20:38:18                 4.0          48.000           20
# 5  2025-01-09 20:38:18                 4.0          34.719        10269
# 6  2025-01-09 20:38:18                 4.0          23.580        10021
# 7  2025-01-09 20:38:18                 4.0          14.780           20
#
#    valor_vendedor  geo_zone_y  country
# 0        2550.600     Chiapas       MX
# 1        1063.800     Chiapas       MX
# 2         885.000     Chiapas       MX
# 3         779.220     Chiapas       MX
# 4         192.000     Chiapas       MX
# 5         138.876     Chiapas       MX
# 6          94.320     Chiapas       MX
# 7          59.120     Chiapas       MX
#
# [8 rows x 22 columns]

# %%
interseccion['precio_total_droguería'].sum()
# Out:
# np.float64(5762.936)

# %%
interseccion['valor_total_vendedor'].sum()
# Out:
# np.float64(5568.2793875)

# %%
from sshtunnel import SSHTunnelForwarder
import pandas as pd
import paramiko
from io import StringIO
import pymysql
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
ssh_host = os.getenv('SSH_HOST')
ssh_port = 22
ssh_user = os.getenv('SSH_USER')
ssh_pkey= '/home/dell/.ssh/id_rsa'
ssh_passphrase = 'hacker' # Reemplaza con tu passphrase si es necesario

# Parámetros de la base de datos
db_host = os.getenv("DB_HOST")
db_port = 3306
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_name = os.getenv("DB_NAME")

# Cargar la clave privada desde el objeto en memoria
my_pkey = paramiko.RSAKey.from_private_key_file(ssh_pkey, password=ssh_passphrase)

# Configurar la conexión SSH
client = paramiko.SSHClient()
client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
client.connect(hostname=ssh_host, port=ssh_port, username=ssh_user, pkey=my_pkey)

# %%
def vendor_prices():
    with SSHTunnelForwarder(
        (ssh_host, ssh_port),
        ssh_username=ssh_user,
        ssh_pkey=my_pkey,  # Usar la clave privada de Paramiko
        remote_bind_address=(db_host, db_port)
    ) as tunnel:
        # Conectar a la base de datos usando pymysql
        connection = pymysql.connect(
            host='127.0.0.1',
            port=tunnel.local_bind_port,
            user=db_user,
            password=db_password,
            db=db_name
        )
        try:
            with connection.cursor() as cursor:
                # Especificar la consulta SQL
                query = """
SELECT vp.product_id,
    vvc.super_catalog_id,
    vp.vendor_id,
    vp.zone_id,
    vp.price_list_id,
    vvc.base_price,    
    vp.percentage,
    (vvc.base_price + vvc.base_price*vp.percentage) AS vendor_price
FROM v_prices vp
JOIN v_vendor_catalog vvc ON vvc.id = vp.product_id
    AND vp.min_price IS NULL
    AND vp.max_price IS NULL

                """

                # Ejecutar la consulta
                cursor.execute(query)
                
                # Obtener los resultados
                results = cursor.fetchall()

                # Convertir los resultados a un DataFrame de pandas
                v_prices = pd.DataFrame(results, columns=[
                'product_id', 
                'super_catalog_id',
                'vendor_id',
                'zone_id',
                'price_list',
                'base_price',
                'percentage',
                'max_price'                
                ])
        except Exception as e:
            print(f"Error: {e}")

        finally:
            connection.close()

    return v_prices

# %%
vendor_price = vendor_prices()
# Out:
# 2025-02-17 13:30:59,439| ERROR   | Password is required for key /home/dell/.ssh/id_rsa

# %%
vendor_price['super_catalog_id'] = vendor_price['super_catalog_id'].astype(str)

# %%
vendor_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393728 entries, 0 to 393727
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   product_id        393728 non-null  int64
#  1   super_catalog_id  393728 non-null  object
#  2   vendor_id         393728 non-null  int64
#  3   zone_id           393728 non-null  int64
#  4   price_list        393728 non-null  int64
#  5   base_price        393594 non-null  object
#  6   percentage        367685 non-null  float64
#  7   max_price         367561 non-null  float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 24.0+ MB

# %%
min_prices_ = (df_pedidos_proveedores_unique
              .groupby(['super_catalog_id'])['precio_minimo']
              .min()
              .reset_index())
min_prices_.columns = ['super_catalog_id', 'precio_minimo_orders']

# 2. Hacer el merge por ambas columnas
df_precios_comparados = pd.merge(
    df_pedidos_proveedores_unique,
    min_prices_,
    on=['super_catalog_id'],
    how='inner'
)

# 3. Calcular diferencia porcentual
df_precios_comparados['diferencia_porcentual'] = (
    (df_precios_comparados['precio_vendedor'].astype(float) - 
     df_precios_comparados['precio_minimo_orders'].astype(float)) / 
    df_precios_comparados['precio_minimo_orders'].astype(float) * 100
)

# 4. Mantener el resto del código igual para la categorización
def categorizar_diferencia(diferencia):
    if 0 < diferencia <= 5:
        return 'hasta_5_porciento'
    elif 5 < diferencia <= 15:
        return 'hasta_15_porciento'
    else:
        return 'mayor_15_porciento'

df_precios_comparados['categoria_diferencia'] = df_precios_comparados['diferencia_porcentual'].apply(categorizar_diferencia)

# 5. Crear el dataframe final
df_analisis_precios = df_precios_comparados[[
    'super_catalog_id',
    'point_of_sale_id',
    'vendor_id',
    'precio_vendedor',
    'precio_minimo_orders',
    'diferencia_porcentual',
    'categoria_diferencia',
    'unidades_pedidas',
    'geo_zone'
]].copy()

# %%
min_prices_
# Out:
#       super_catalog_id  precio_minimo_orders
# 0             42270010                58.670
# 1             42270027                83.580
# 2             42270034                74.450
# 3             42277392                28.805
# 4             42332862                42.000
# ...                ...                   ...
# 8557     8904091184712               481.270
# 8558     8904091189120               598.970
# 8559     8907730000039                72.900
# 8560     9002240001022               113.150
# 8561     9660188770044                16.190
#
# [8562 rows x 2 columns]

# %%
min_prices_['super_catalog_id'] = min_prices_['super_catalog_id'].astype(str)

# %%
vendor_price
# Out:
#         product_id super_catalog_id  vendor_id  zone_id  price_list  \
# 0           192286    7502216804203       1142      830         193
# 1           192305    7502216798373       1142      830         193
# 2           192307    7502216804869       1142      830         193
# 3           197346    7795371458231       1142      828         194
# 4           197347    7795371458378       1142      828         194
# ...            ...              ...        ...      ...         ...
# 393723      407593    7502211784029       1358     1701         621
# 393724      401486    7502211784036       1358     1701         621
# 393725      401456    7502259890119       1358     1701         621
# 393726      401457    7502259891376       1358     1701         621
# 393727      407054    7502009747199       1358     1701         621
#
#         base_price  percentage     max_price
# 0          29.1830     -0.1000     26.264700
# 1          15.9390     -0.1000     14.345100
# 2          14.4760     -0.1000     13.028400
# 3       27862.0000     -0.2000  22289.599917
# 4       13793.0000     -0.2000  11034.399959
# ...            ...         ...           ...
# 393723     34.0900      0.0364     35.330876
# 393724     40.0100      0.0364     41.466364
# 393725     41.5100      0.0364     43.020964
# 393726     41.5100      0.0364     43.020964
# 393727     58.4900      0.0364     60.619036
#
# [393728 rows x 8 columns]

# %%
vendor_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393728 entries, 0 to 393727
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   product_id        393728 non-null  int64
#  1   super_catalog_id  393728 non-null  object
#  2   vendor_id         393728 non-null  int64
#  3   zone_id           393728 non-null  int64
#  4   price_list        393728 non-null  int64
#  5   base_price        393594 non-null  object
#  6   percentage        367685 non-null  float64
#  7   max_price         367561 non-null  float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 24.0+ MB

# %%
min_prices_.to_csv('min_prices_pos_vendors.csv')

# %%
min_prices_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8562 entries, 0 to 8561
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   super_catalog_id      8562 non-null   object
#  1   precio_minimo_orders  8562 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 133.9+ KB

# %%
df_vendors = vendor_prices()
# Out:
# 2025-02-17 13:31:11,810| ERROR   | Password is required for key /home/dell/.ssh/id_rsa

# %%
df_vendors['super_catalog_id'] = df_vendors['super_catalog_id'].astype(str)

# %%
df_vendors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393728 entries, 0 to 393727
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   product_id        393728 non-null  int64
#  1   super_catalog_id  393728 non-null  object
#  2   vendor_id         393728 non-null  int64
#  3   zone_id           393728 non-null  int64
#  4   price_list        393728 non-null  int64
#  5   base_price        393594 non-null  object
#  6   percentage        367685 non-null  float64
#  7   max_price         367561 non-null  float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 24.0+ MB

# %%
    # Primero, obtener los precios de los vendedores
    
    # Leer el CSV de precios mínimos
df_min_prices = pd.read_csv('min_prices_pos_vendors.csv')
df_min_prices['super_catalog_id'] = df_min_prices['super_catalog_id'].astype(str)
    # Merge de los dataframes usando super_catalog_id como clave
df_merged = pd.merge(
        df_vendors[['super_catalog_id','vendor_id','max_price']],
        df_min_prices[['super_catalog_id', 'precio_minimo_orders']],
        on='super_catalog_id',
        how='left'
    )
    
    # Calcular el precio mínimo (precio_minimo_orders - 1%)
df_merged['min_price'] = df_merged['precio_minimo_orders'] * 0.99
    
    # El precio máximo ya viene en la columna 'max_price' de df_vendors

# %%
merged= df_merged.dropna().drop_duplicates()

# %%
merged.isna().sum()
# Out:
# super_catalog_id        0
# vendor_id               0
# max_price               0
# precio_minimo_orders    0
# min_price               0
# dtype: int64

# %%
merged
# Out:
#        super_catalog_id  vendor_id   max_price  precio_minimo_orders  \
# 0         7502216804203       1142   26.264700                 23.49
# 1         7502216798373       1142   14.345100                 12.50
# 2         7502216804869       1142   13.028400                  9.36
# 12        7501287621009       1141  863.199997                360.00
# 13        7501043100410       1141  143.199999                139.28
# ...                 ...        ...         ...                   ...
# 392289    7501563370997       1358   11.068752                 10.49
# 392700    7502006920038       1358   20.852368                 17.52
# 393236    7501258207010       1358   69.003512                 45.75
# 393309    7501349025943       1358   35.237600                 31.29
# 393529     780083140205       1358   32.159492                 28.83
#
#         min_price
# 0         23.2551
# 1         12.3750
# 2          9.2664
# 12       356.4000
# 13       137.8872
# ...           ...
# 392289    10.3851
# 392700    17.3448
# 393236    45.2925
# 393309    30.9771
# 393529    28.5417
#
# [55745 rows x 5 columns]

# %%
df_pedidos_proveedores_unique[df_pedidos_proveedores_unique['super_catalog_id']==7501482202225]
# Out:
#        point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 55634              1170     7501482202225              60.0          111.6
#
#       geo_zone  vendor_id    name  base_price  percentage  precio_vendedor  \
# 55634  Hidalgo       1152  México     40.8716         0.0          40.8716
#
#        precio_total_vendedor  status
# 55634               2452.296     1.0

# %%
df_pedidos_proveedores_unique[(df_pedidos_proveedores_unique['point_of_sale_id']==1238)&(df_pedidos_proveedores_unique['super_catalog_id']==7501482202225)]
# Out:
# Empty DataFrame
# Columns: [point_of_sale_id, super_catalog_id, unidades_pedidas, precio_minimo, geo_zone, vendor_id, name, base_price, percentage, precio_vendedor, precio_total_vendedor, status]
# Index: []

# %%
merged_filtered = merged[merged['max_price']< merged['min_price']]

# %%
merged_filtered
# Out:
#        super_catalog_id  vendor_id    max_price  precio_minimo_orders  \
# 15        7501201310026       1141  1623.999994              2377.380
# 18         759684031243       1151    18.710000                19.690
# 109       7502208894687       1151    69.610000                73.060
# 191        759684151538       1151    10.860000                14.500
# 289       7501125152061       1151    16.880000                18.300
# ...                 ...        ...          ...                   ...
# 389168    7501342800509       1152    24.546240                25.420
# 389170    7501482202225       1152    39.478526               111.600
# 389338    7502274790968       1152     4.397911                 4.480
# 391419    7503000422696       1358    23.225724                24.382
# 391600    7501123017300       1358    40.616516                71.880
#
#          min_price
# 15      2353.60620
# 18        19.49310
# 109       72.32940
# 191       14.35500
# 289       18.11700
# ...            ...
# 389168    25.16580
# 389170   110.48400
# 389338     4.43520
# 391419    24.13818
# 391600    71.16120
#
# [6036 rows x 5 columns]

# %%
merged_filtered['vendor_id'].value_counts()
# Out:
# vendor_id
# 1152    2128
# 1142     847
# 1161     416
# 1159     392
# 1150     363
# 1275     328
# 1303     213
# 1164     201
# 1309     183
# 1358     177
# 1350     130
# 1373     125
# 1156      99
# 1239      90
# 1151      87
# 1153      80
# 1163      71
# 1141      33
# 1155      31
# 1160      30
# 1157       6
# 1162       6
# Name: count, dtype: int64

# %%
df_min_prices[df_min_prices['super_catalog_id']== '7501201310026']
# Out:
#       Unnamed: 0 super_catalog_id  precio_minimo_orders
# 3627        3627    7501201310026               2377.38

# %%
# Obtener el dataframe con los rangos de precios
merged[(merged['vendor_id']==1141)&(merged['super_catalog_id']=='7501201310026')]
# Para verificar los resultados
# Out:
#      super_catalog_id  vendor_id    max_price  precio_minimo_orders  min_price
# 15      7501201310026       1141  1623.999994               2377.38  2353.6062
# 3280    7501201310026       1141  2030.000000               2377.38  2353.6062
# 3420    7501201310026       1141  1826.999997               2377.38  2353.6062

# %%
df_pedidos_proveedores_unique[df_pedidos_proveedores_unique['super_catalog_id']==7501201310026]
# Out:
#        point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 39015              1610     7501201310026               5.0        2377.38
#
#          geo_zone  vendor_id    name  base_price  percentage  precio_vendedor  \
# 39015  Nuevo León       1156  México     2529.13         0.0          2529.13
#
#        precio_total_vendedor  status
# 39015               12645.65     NaN

# %%
orders[orders['super_catalog_id']==7501482202225]
# Out:
#        point_of_sale_id  super_catalog_id  order_id           order_date  \
# 28066              1238     7501482202225    235801  2025-01-06 02:54:42
# 37112              1170     7501482202225    243528  2025-01-27 21:23:16
#
#        unidades_pedidas  precio_minimo  vendor_id  valor_vendedor geo_zone  \
# 28066               2.0          40.86         20           81.72  Hidalgo
# 37112              60.0         111.60         20         6696.00  Hidalgo
#
#       country
# 28066      MX
# 37112      MX

# %%
min_prices_global = (orders
              .groupby(['super_catalog_id'])['precio_minimo']
              .min()
              .reset_index())
min_prices_global.columns = ['super_catalog_id', 'precio_minimo_orders']

# 2. Hacer el merge por ambas columnas
df_precios_comparados = pd.merge(
    orders,
    min_prices_,
    on=['super_catalog_id'],
    how='inner'
)

# 3. Calcular diferencia porcentual
df_precios_comparados['diferencia_porcentual'] = (
    (df_precios_comparados['valor_vendedor'].astype(float) - 
     df_precios_comparados['precio_minimo_orders'].astype(float)) / 
    df_precios_comparados['precio_minimo_orders'].astype(float) * 100
)

# 4. Mantener el resto del código igual para la categorización
def categorizar_diferencia(diferencia):
    if 0 < diferencia <= 5:
        return 'hasta_5_porciento'
    elif 5 < diferencia <= 15:
        return 'hasta_15_porciento'
    else:
        return 'mayor_15_porciento'

df_precios_comparados['categoria_diferencia'] = df_precios_comparados['diferencia_porcentual'].apply(categorizar_diferencia)

# 5. Crear el dataframe final
df_analisis_precios = df_precios_comparados[[
    'super_catalog_id',
    'point_of_sale_id',
    'vendor_id',
    'valor_vendedor',
    'precio_minimo_orders',
    'diferencia_porcentual',
    'categoria_diferencia',
    'unidades_pedidas',
    'geo_zone'
]].copy()

# %%
min_prices_global['super_catalog_id'].nunique()
# Out:
# 12473

# %%
df_precios_comparados.to_csv('productos_clasificados.csv', index=False, encoding='utf-8')

# %%
df_precios_comparados['categoria_diferencia'].value_counts()
# Out:
# categoria_diferencia
# mayor_15_porciento    72072
# hasta_15_porciento     6206
# hasta_5_porciento      3958
# Name: count, dtype: int64
