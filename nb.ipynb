# %%
import pandas as pd
top = pd.read_csv('top_5_productos_geozona.csv')
top[top['point_of_sale_id']==721]
# Out:
#       point_of_sale_id  super_catalog_id  unidades_pedidas  precio_minimo  \
# 610                721     7501299300909               7.0         145.79
# 633                721     7502214983375              40.0          41.39
# 641                721     7501314701711               4.0         240.04
# 653                721     7501328980119               2.0         387.55
# 685                721     7501089804327               2.0         420.44
# ...                ...               ...               ...            ...
# 1576               721     7502240450773               1.0          23.41
# 1580               721     7502216797376               3.0           7.41
# 1585               721     7502001162518               1.0          29.40
# 1591               721      780083146863               1.0          20.56
# 1598               721     7503001007069               1.0          19.01
#
#      geo_zone  vendor_id    name  base_price  percentage  precio_vendedor  \
# ...
